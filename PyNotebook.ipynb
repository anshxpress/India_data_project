# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session

# %% [markdown]
# 1. /kaggle/input/india-census/hlpca-colnames.csv
# 1. /kaggle/input/india-census/india-districts-census-2011.csv
# 1. /kaggle/input/india-census/india_census_housing-hlpca-full.csv
# 1. /kaggle/input/indian-census-data-with-geospatial-indexing/district wise centroids.csv
# 1. /kaggle/input/indian-census-data-with-geospatial-indexing/district wise population and centroids.csv
# 1. /kaggle/input/indian-census-data-with-geospatial-indexing/district wise population for year 2001 and 2011.csv
# 1. /kaggle/input/indian-census-data-with-geospatial-indexing/state wise centroids_2001.csv
# 1. /kaggle/input/indian-census-data-with-geospatial-indexing/state wise centroids_2011.csv

# %%
import pandas as pd
import numpy as np
latlong = pd.read_csv(/kaggle/input/indian-census-data-with-geospatial-indexing.cs)
latlong

# %%
latlong = pd.read_csv('/kaggle/input/indian-census-data-with-geospatial-indexing/district wise centroids.csv')
latlong
# Out:
#                    State           District   Latitude  Longitude
# 0    Andaman and Nicobar    Andaman Islands  12.382571  92.822911
# 1    Andaman and Nicobar    Nicobar Islands   7.835291  93.511601
# 2         Andhra Pradesh           Adilabad  19.284514  78.813212
# 3         Andhra Pradesh          Anantapur  14.312066  77.460158
# 4         Andhra Pradesh           Chittoor  13.331093  78.927639
# ..                   ...                ...        ...        ...
# 589          West Bengal  North 24 Parganas  22.062388  88.877940
# 590          West Bengal           Puruliya  23.254192  86.396853
# 591          West Bengal  South 24 Parganas  21.854428  88.445370
# 592          West Bengal     Uttar Dinajpur  26.044619  88.235952
# 593          West Bengal     West Midnapore  22.354897  87.231014
#
# [594 rows x 4 columns]

# %%
latlong.isnull().sum()
# Out:
# State        0
# District     0
# Latitude     0
# Longitude    0
# dtype: int64

# %%
latlong.duplicated().sum()
# Out:
# 0

# %%
census = pd.read_csv('/kaggle/input/india-census/india-districts-census-2011.csv')
census
# Out:
#      District code                   State name              District name  \
# 0                1            JAMMU AND KASHMIR                    Kupwara
# 1                2            JAMMU AND KASHMIR                     Badgam
# 2                3            JAMMU AND KASHMIR                Leh(Ladakh)
# 3                4            JAMMU AND KASHMIR                     Kargil
# 4                5            JAMMU AND KASHMIR                      Punch
# ..             ...                          ...                        ...
# 635            636                  PONDICHERRY                       Mahe
# 636            637                  PONDICHERRY                   Karaikal
# 637            638  ANDAMAN AND NICOBAR ISLANDS                   Nicobars
# 638            639  ANDAMAN AND NICOBAR ISLANDS  North  AND Middle Andaman
# 639            640  ANDAMAN AND NICOBAR ISLANDS              South Andaman
#
# ...

# %%
house = pd.read_csv('/kaggle/input/india-census/india_census_housing-hlpca-full.csv')
house
# Out:
#       State Code                 State Name  District Code  \
# 0              1            JAMMU & KASHMIR              1
# 1              1            JAMMU & KASHMIR              1
# 2              1            JAMMU & KASHMIR              1
# 3              1            JAMMU & KASHMIR              2
# 4              1            JAMMU & KASHMIR              2
# ...          ...                        ...            ...
# 1903          35  ANDAMAN & NICOBAR ISLANDS            639
# 1904          35  ANDAMAN & NICOBAR ISLANDS            639
# 1905          35  ANDAMAN & NICOBAR ISLANDS            640
# 1906          35  ANDAMAN & NICOBAR ISLANDS            640
# 1907          35  ANDAMAN & NICOBAR ISLANDS            640
#
#                 District Name  Tehsil Code              Tehsil Name  \
# 0                     Kupwara            0                  Kupwara
# 1                     Kupwara            0                  Kupwara
# ...

# %%
cols = ['District code', 'District name', 'Population', 'Male','Female','Literate','Housholds_with_Electric_Lighting','Households_with_Internet']
census[cols]
# Out:
#      District code              District name  Population    Male  Female  \
# 0                1                    Kupwara      870354  474190  396164
# 1                2                     Badgam      753745  398041  355704
# 2                3                Leh(Ladakh)      133487   78971   54516
# 3                4                     Kargil      140802   77785   63017
# 4                5                      Punch      476835  251899  224936
# ..             ...                        ...         ...     ...     ...
# 635            636                       Mahe       41816   19143   22673
# 636            637                   Karaikal      200222   97809  102413
# 637            638                   Nicobars       36842   20727   16115
# 638            639  North  AND Middle Andaman      105597   54861   50736
# 639            640              South Andaman      238142  127283  110859
#
#      Literate  Housholds_with_Electric_Lighting  Households_with_Internet
# ...

# %%
census=census[cols]
census
# Out:
#      District code              District name  Population    Male  Female  \
# 0                1                    Kupwara      870354  474190  396164
# 1                2                     Badgam      753745  398041  355704
# 2                3                Leh(Ladakh)      133487   78971   54516
# 3                4                     Kargil      140802   77785   63017
# 4                5                      Punch      476835  251899  224936
# ..             ...                        ...         ...     ...     ...
# 635            636                       Mahe       41816   19143   22673
# 636            637                   Karaikal      200222   97809  102413
# 637            638                   Nicobars       36842   20727   16115
# 638            639  North  AND Middle Andaman      105597   54861   50736
# 639            640              South Andaman      238142  127283  110859
#
#      Literate  Housholds_with_Electric_Lighting  Households_with_Internet
# ...

# %%
latlong
# Out:
#                    State           District   Latitude  Longitude
# 0    Andaman and Nicobar    Andaman Islands  12.382571  92.822911
# 1    Andaman and Nicobar    Nicobar Islands   7.835291  93.511601
# 2         Andhra Pradesh           Adilabad  19.284514  78.813212
# 3         Andhra Pradesh          Anantapur  14.312066  77.460158
# 4         Andhra Pradesh           Chittoor  13.331093  78.927639
# ..                   ...                ...        ...        ...
# 589          West Bengal  North 24 Parganas  22.062388  88.877940
# 590          West Bengal           Puruliya  23.254192  86.396853
# 591          West Bengal  South 24 Parganas  21.854428  88.445370
# 592          West Bengal     Uttar Dinajpur  26.044619  88.235952
# 593          West Bengal     West Midnapore  22.354897  87.231014
#
# [594 rows x 4 columns]

# %%
final = latlong.merge(census,left_on='District',right_on='District name').drop(columns=['District name'])

# %%
final
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population     Male   Female  Literate  Housholds_with_Electric_Lighting  \
# ...

# %%
final['Sex Ratio'] = round((final['Female']/final['Male'])*100)
final['Sex Ratio'].reset_index()
# Out:
#      index  Sex Ratio
# 0        0      100.0
# 1        1       98.0
# 2        2      100.0
# 3        3      101.0
# 4        4      100.0
# ..     ...        ...
# 512    512       94.0
# 513    513       96.0
# 514    514       95.0
# 515    515       96.0
# 516    516       94.0
#
# [517 rows x 2 columns]

# %%
final
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population  Housholds_with_Electric_Lighting  Households_with_Internet  \
# ...

# %%
final
# Out:
#               State        District   Latitude  Longitude  District code  \
# 0    Andhra Pradesh        Adilabad  19.284514  78.813212            532
# 1    Andhra Pradesh       Anantapur  14.312066  77.460158            553
# 2    Andhra Pradesh        Chittoor  13.331093  78.927639            554
# 3    Andhra Pradesh   East Godavari  16.782718  82.243207            545
# 4    Andhra Pradesh          Guntur  15.884926  80.586576            548
# ..              ...             ...        ...        ...            ...
# 512     West Bengal          Maldah  25.080268  88.171917            332
# 513     West Bengal     Murshidabad  24.259507  88.168169            333
# 514     West Bengal           Nadia  23.564110  88.582930            336
# 515     West Bengal        Puruliya  23.254192  86.396853            340
# 516     West Bengal  Uttar Dinajpur  26.044619  88.235952            330
#
#      Population  Housholds_with_Electric_Lighting  Households_with_Internet  \
# ...

# %%
final.to_csv('india.csv',index=False)

# %%
list_of_state = list(final['State'].unique())
list_of_state.insert(0,'Over-All India')

# %%
list_of_state
# Out:
# ['Over-All India',
#  'Andhra Pradesh',
#  'Arunachal Pradesh',
#  'Assam',
#  'Bihar',
#  'Maharashtra',
#  'Chandigarh',
#  'Chhattisgarh',
#  'Himachal Pradesh',
#  'Daman and Diu',
#  'Gujarat',
#  'Goa',
#  'Haryana',
#  'Uttar Pradesh',
#  'Jammu and Kashmir',
#  'Jharkhand',
#  'Karnataka',
#  'Kerala',
#  'Madhya Pradesh',
#  'Manipur',
#  'Meghalaya',
#  'Mizoram',
#  'Nagaland',
#  'Orissa',
#  'Puducherry',
#  'Punjab',
#  'Rajasthan',
#  'Sikkim',
#  'Tamil Nadu',
#  'Tripura',
#  'Uttaranchal',
#  'West Bengal']

# %%
sorted(final.columns[5:])
# Out:
# ['Households_with_Internet',
#  'Housholds_with_Electric_Lighting',
#  'Literacy rate',
#  'Population',
#  'Sex Ratio']
